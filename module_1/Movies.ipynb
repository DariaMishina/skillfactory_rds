# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter
print(os.listdir("C:/Users/DariaMishina/skillfactory_rds/module_1"))
# Out:
# ['.ipynb_checkpoints', 'data.csv', 'draft 11 task.ipynb', 'draft 12 task.ipynb', 'draft 21.ipynb', 'draft 36 task.ipynb', 'draft task 16.ipynb', 'draft task 17.ipynb', 'draft task 18.ipynb', 'draft task 19.ipynb', 'draft task 22.ipynb', 'draft task 23.ipynb', 'draft task 26.ipynb', 'draft task 27 28 29 30.ipynb', 'draft task 31.ipynb', 'draft task 32.ipynb', 'draft task 33.ipynb', 'draft task 34.ipynb', 'draft task 35.ipynb', 'draft.ipynb', '[SF-DST] Movies IMBD DM-Copy1.ipynb']

# %%
data = pd.read_csv('C:/Users/DariaMishina/skillfactory_rds/module_1/data.csv')
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
len(data)
# Out:
# 1890

# %% [markdown]
# # Предобработка датасета

# %%
answer_ls = [] # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете

# %%
data.describe()
# Out:
#         popularity        budget       revenue      runtime   vote_count  \
# count  1890.000000  1.890000e+03  1.890000e+03  1890.000000  1890.000000
# mean      1.560611  5.450696e+07  1.552890e+08   109.653439   785.666667
# std       1.849471  4.931705e+07  2.146386e+08    18.013641  1068.725880
# min       0.010335  5.000000e+06  2.033165e+06    63.000000    10.000000
# 25%       0.643284  2.000000e+07  3.434007e+07    97.000000   164.000000
# 50%       1.065065  3.800000e+07  8.358664e+07   106.500000   389.000000
# 75%       1.804537  7.200000e+07  1.782136e+08   120.000000   937.750000
# max      32.985763  4.250000e+08  2.781506e+09   214.000000  9767.000000
#
#        vote_average  release_year
# count   1890.000000   1890.000000
# mean       6.140899   2007.861905
# std        0.764584      4.467929
# min        3.300000   2000.000000
# 25%        5.600000   2004.000000
# 50%        6.100000   2008.000000
# 75%        6.600000   2012.000000
# ...

# %%
data.columns
# Out:
# Index(['imdb_id', 'popularity', 'budget', 'revenue', 'original_title', 'cast',
#        'director', 'tagline', 'overview', 'runtime', 'genres',
#        'production_companies', 'release_date', 'vote_count', 'vote_average',
#        'release_year'],
#       dtype='object')

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
#первый вариант
data[data.budget == data.budget.max()].original_title
# Out:
# 491    The Warrior's Way
# Name: original_title, dtype: object

# %%
#второй вариант
data.original_title[data.budget.idxmax()]
# Out:
# "The Warrior's Way"

# %%
# тут вводим ваш ответ и добавлем в его список ответов (сейчас для примера стоит "1")
answer_ls.append(4)

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
#первый вариант
data[data.runtime == data.runtime.max()].original_title
# Out:
# 1158    Gods and Generals
# Name: original_title, dtype: object

# %%
#второй вариант в 2 шага
# нашла максимум продолжительности
data.runtime.max()
# Out:
# 214

# %%
#отфильтровала по максимуму продолжительности
data[data.runtime == 214]
# Out:
#         imdb_id  popularity    budget   revenue     original_title  \
# 1158  tt0279111    0.469518  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1158  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1158  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1158  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1158  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_count  vote_average  release_year
# 1158          23           5.8          2003

# %%
data.original_title[data.runtime.idxmax()]
# Out:
# 'Gods and Generals'

# %%
answer_ls.append(2)

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
#первый способ
data[data.runtime == data.runtime.min()].original_title
# Out:
# 769    Winnie the Pooh
# Name: original_title, dtype: object

# %%
#второй способо
data[data.runtime == data.runtime.min()]
# Out:
#        imdb_id  popularity    budget   revenue   original_title  \
# 769  tt1449283    1.425344  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 769  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 769  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 769  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 769  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_count  vote_average  release_year
# 769    4/13/2011         174           6.8          2011

# %%
#третий способ
data.original_title[data.runtime.idxmin()]
# Out:
# 'Winnie the Pooh'

# %%
answer_ls.append(3)

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
data.runtime.mean()
# Out:
# 109.65343915343915

# %%
answer_ls.append(2)

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
data.describe()
#для медианы см строку где 50% для колонки runtime
# Out:
#         popularity        budget       revenue      runtime   vote_count  \
# count  1890.000000  1.890000e+03  1.890000e+03  1890.000000  1890.000000
# mean      1.560611  5.450696e+07  1.552890e+08   109.653439   785.666667
# std       1.849471  4.931705e+07  2.146386e+08    18.013641  1068.725880
# min       0.010335  5.000000e+06  2.033165e+06    63.000000    10.000000
# 25%       0.643284  2.000000e+07  3.434007e+07    97.000000   164.000000
# 50%       1.065065  3.800000e+07  8.358664e+07   106.500000   389.000000
# 75%       1.804537  7.200000e+07  1.782136e+08   120.000000   937.750000
# max      32.985763  4.250000e+08  2.781506e+09   214.000000  9767.000000
#
#        vote_average  release_year
# count   1890.000000   1890.000000
# mean       6.140899   2007.861905
# std        0.764584      4.467929
# min        3.300000   2000.000000
# 25%        5.600000   2004.000000
# 50%        6.100000   2008.000000
# 75%        6.600000   2012.000000
# ...

# %%
answer_ls.append(1)

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
#создаем новую колонку с прибылью как разницу между сборами и бюджетом
data['profit'] = data['revenue'] - data['budget']

# %%
data[data.profit == data.profit.max()].original_title
# Out:
# 239    Avatar
# Name: original_title, dtype: object

# %%
data.original_title[data.profit.idxmax()]
# Out:
# 'Avatar'

# %%
data[data.profit == data.profit.max()]
# Out:
#        imdb_id  popularity     budget     revenue original_title  \
# 239  tt0499549    9.432768  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_count  vote_average  release_year      profit
# 239        8458           7.1          2009  2544505847

# %%
answer_ls.append(5)

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
data[data.profit == data.profit.min()].original_title
# Out:
# 491    The Warrior's Way
# Name: original_title, dtype: object

# %%
data[data.profit == data.profit.min()]
# Out:
#        imdb_id  popularity     budget   revenue     original_title  \
# 491  tt1032751     0.25054  425000000  11087569  The Warrior's Way
#
#                                                   cast    director  \
# 491  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee
#
#                      tagline  \
# 491  Assassin. Hero. Legend.
#
#                                               overview  runtime  \
# 491  An Asian assassin (Dong-gun Jang) is forced to...      100
#
#                                         genres      production_companies  \
# 491  Adventure|Fantasy|Action|Western|Thriller  Boram Entertainment Inc.
#
#     release_date  vote_count  vote_average  release_year     profit
# 491    12/2/2010          74           6.4          2010 -413912431

# %%
data.original_title[data.profit.idxmin()]
# Out:
# "The Warrior's Way"

# %%
answer_ls.append(2)

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
#отфильтровываем датафрем по тем фильмам, у ктр прибыль больше 0
profitfilms = data[data.profit > 0]

# %%
#находим длину нового датафрейма
len(profitfilms)
# Out:
# 1478

# %%
answer_ls.append(1)

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
#отфильтровываем датафрейм по году
yeardata = data[data.release_year == 2008]

# %%
yeardata[yeardata.profit == yeardata.profit.max()]
# Out:
#        imdb_id  popularity     budget     revenue   original_title  \
# 600  tt0468569    8.466668  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 600  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 600  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 600      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 600  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_count  vote_average  release_year     profit
# 600        8432           8.1          2008  816921825

# %%
yeardata.original_title[yeardata.profit.idxmax()]
# Out:
# 'The Dark Knight'

# %%
answer_ls.append(4)

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
#находим значение минимума прибыли с 2012 и по 2014
data[(data.release_year >= 2012)&(data.release_year <= 2014)].profit.min()
# Out:
# -165710090

# %%
# по полученному значению минимума прибыли отфильтровываем  первоначальный датафрейм
data[data.profit == -165710090]
# Out:
#         imdb_id  popularity     budget   revenue   original_title  \
# 1246  tt1210819     1.21451  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1246  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1246  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1246  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1246  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1246  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_count  vote_average  release_year     profit
# 1246        1607           6.0          2013 -165710090

# %%
#или так - отфильтровываем датафрейм по годам
data20122014 = data[(data.release_year >= 2012)&(data.release_year <= 2014)]

# %%
#из нового датафрейма извлекаем фильм с минимальной прибылью
data20122014.original_title[data20122014.profit.idxmin()]
# Out:
# 'The Lone Ranger'

# %%
answer_ls.append(5)

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
Counter(data.genres.str.split('|').sum()).most_common()
# Out:
# [('Drama', 782),
#  ('Comedy', 683),
#  ('Thriller', 597),
#  ('Action', 583),
#  ('Adventure', 416),
#  ('Crime', 315),
#  ('Romance', 308),
#  ('Family', 260),
#  ('Science Fiction', 248),
#  ('Fantasy', 223),
#  ('Horror', 176),
#  ('Mystery', 168),
#  ('Animation', 139),
#  ('Music', 64),
#  ('History', 62),
#  ('War', 58),
#  ('Western', 20),
#  ('Documentary', 8),
#  ('Foreign', 2)]

# %%
answer_ls.append(3)

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
#отфильтровываем датафрейм только по прибыльным фильмам
profitfilms = data[data.profit > 0]

# %%
Counter(profitfilms.genres.str.split('|').sum()).most_common()
# Out:
# [('Drama', 560),
#  ('Comedy', 551),
#  ('Thriller', 446),
#  ('Action', 444),
#  ('Adventure', 337),
#  ('Romance', 242),
#  ('Crime', 231),
#  ('Family', 226),
#  ('Science Fiction', 195),
#  ('Fantasy', 188),
#  ('Horror', 150),
#  ('Animation', 120),
#  ('Mystery', 119),
#  ('Music', 47),
#  ('History', 46),
#  ('War', 41),
#  ('Western', 12),
#  ('Documentary', 7)]

# %%
answer_ls.append(1)

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
#первый способ
data.describe(include = ['object']).director.top
# Out:
# 'Steven Soderbergh'

# %%
#второй способ
Counter(data.director.str.split('|').sum()).most_common()
# Out:
# [('Steven Soderbergh', 13),
#  ('Ridley Scott', 12),
#  ('Clint Eastwood', 12),
#  ('Robert Rodriguez', 11),
#  ('Steven Spielberg', 10),
#  ('Shawn Levy', 10),
#  ('Peter Farrelly', 10),
#  ('Bobby Farrelly', 9),
#  ('Tim Burton', 9),
#  ('Antoine Fuqua', 8),
#  ('Ron Howard', 8),
#  ('M. Night Shyamalan', 8),
#  ('Christopher Nolan', 8),
#  ('Peter Jackson', 8),
#  ('Michael Bay', 8),
#  ('Brett Ratner', 8),
#  ('Todd Phillips', 8),
#  ('Adam Shankman', 8),
#  ('Gore Verbinski', 8),
#  ('Quentin Tarantino', 7),
#  ('Paul W.S. Anderson', 7),
#  ('Lasse HallstrÃ¶m', 7),
#  ('Dennis Dugan', 7),
#  ('Marc Forster', 7),
#  ('Francis Lawrence', 6),
#  ('Adam McKay', 6),
#  ('Robert Zemeckis', 6),
#  ('Andy Fickman', 6),
#  ('David Fincher', 6),
#  ('Tim Story', 6),
#  ('Zack Snyder', 6),
#  ('Robert Luketic', 6),
#  ('Steve Carr', 6),
#  ('Sam Raimi', 6),
#  ('Tony Scott', 6),
#  ('Joel Coen', 6),
#  ('Martin Scorsese', 6),
#  ('Danny Boyle', 6),
#  ('Louis Leterrier', 6),
# ...

# %%
answer_ls.append(1)

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
#отфильтровываем датафрейм только по прибыльным фильмам
profitfilms = data[data.profit > 0]

# %%
Counter(profitfilms .director.str.split('|').sum()).most_common()
# Out:
# [('Ridley Scott', 12),
#  ('Steven Spielberg', 10),
#  ('Clint Eastwood', 10),
#  ('Steven Soderbergh', 10),
#  ('Shawn Levy', 9),
#  ('Tim Burton', 9),
#  ('Antoine Fuqua', 8),
#  ('Christopher Nolan', 8),
#  ('Peter Jackson', 8),
#  ('Michael Bay', 8),
#  ('Brett Ratner', 8),
#  ('Peter Farrelly', 8),
#  ('Robert Rodriguez', 8),
#  ('M. Night Shyamalan', 7),
#  ('Bobby Farrelly', 7),
#  ('Todd Phillips', 7),
#  ('Adam Shankman', 7),
#  ('Quentin Tarantino', 6),
#  ('Francis Lawrence', 6),
#  ('Adam McKay', 6),
#  ('Robert Zemeckis', 6),
#  ('Andy Fickman', 6),
#  ('David Fincher', 6),
#  ('Tim Story', 6),
#  ('Zack Snyder', 6),
#  ('Ron Howard', 6),
#  ('Sam Raimi', 6),
#  ('Joel Coen', 6),
#  ('Louis Leterrier', 6),
#  ('Dennis Dugan', 6),
#  ('Paul W.S. Anderson', 6),
#  ('Gore Verbinski', 6),
#  ('Peter Segal', 6),
#  ('Raja Gosnell', 6),
#  ('J.J. Abrams', 5),
#  ('Sam Mendes', 5),
#  ('Jaume Collet-Serra', 5),
#  ('F. Gary Gray', 5),
#  ('Guy Ritchie', 5),
# ...

# %%
data[data.profit > 0].director.value_counts()
# Out:
# Ridley Scott               12
# Steven Soderbergh          10
# Clint Eastwood             10
# Steven Spielberg           10
# Shawn Levy                  9
#                            ..
# Charles Herman-Wurmfeld     1
# Andrew Douglas              1
# Adrian Lyne                 1
# Andrew Erwin|Jon Erwin      1
# Michael Hoffman             1
# Name: director, Length: 774, dtype: int64

# %%
answer_ls.append(4)

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
#сгруппировываем по режиссерам и суммируем
data1 = data.groupby(['director']).sum()

# %%
#выбираем из отфильтрованного датафрейма самую большую прибыль
data1[data1.profit == data1.profit.max()]
# Out:
#                popularity      budget     revenue  runtime  vote_count  \
# director
# Peter Jackson   45.679675  1288000000  6490593685     1355       31197
#
#                vote_average  release_year      profit
# director
# Peter Jackson          58.1         16059  5202593685

# %%
#второй вариант, группируем прибыль по директорам, суммируем, сортируем по убыванию
data2 = data.groupby(['director'])['profit'].sum().sort_values(ascending=False)
data2
# Out:
# director
# Peter Jackson            5202593685
# David Yates              3379295625
# Christopher Nolan        3162548502
# J.J. Abrams              2839169916
# Michael Bay              2760938960
#                             ...
# David Bowers|Sam Fell     -84540684
# Peter Hyams               -86956545
# Ron Underwood             -92896027
# James L. Brooks           -96289726
# Sngmoo Lee               -413912431
# Name: profit, Length: 958, dtype: int64

# %%
answer_ls.append(5)

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
#делаем список из всех актеров, разделяя его по |
d = data.cast.str.split('|').sum()

# %%
#пробегаемся по списку всех актеров и достаем того, у ктр максимальная прибыль
pd.Series({x: data[data.cast.str.contains(x)].profit.sum() 
           for x in d}).idxmax()
# Out:
# 'Emma Watson'

# %%
answer_ls.append(1)

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
#отфильтровываем датафрейм по 2012 году
data2012 = data[data.release_year == 2012]

# %%
#из отфильтрованного датафрейма группируем по году сумму прибыли 
data3 = data2012.groupby(['cast'])['profit'].sum().sort_values(ascending=True)
data3
# Out:
# cast
# Kirsten Dunst|Jim Sturgess|Timothy Spall|James Kidnie|Heidi Hawkins                   -51893525
# Nicolas Cage|Malin Ã…kerman|Josh Lucas|Sami Gayle|Danny Huston                        -32893443
# Chris Hemsworth|Josh Hutcherson|Isabel Lucas|Adrianne Palicki|Jeffrey Dean Morgan     -20193217
# Eddie Murphy|Allison Janney|Cliff Curtis|Clark Duke|Kerry Washington                  -17955723
# Kristen Stewart|Garrett Hedlund|Sam Riley|Kirsten Dunst|Tom Sturridge                 -16215682
#                                                                                         ...
# Ian McKellen|Martin Freeman|Richard Armitage|Andy Serkis|Cate Blanchett               767003568
# John Leguizamo|Ray Romano|Chris Wedge|Denis Leary|Seann William Scott                 782244782
# Christian Bale|Michael Caine|Gary Oldman|Anne Hathaway|Tom Hardy                      831041287
# Daniel Craig|Judi Dench|Javier Bardem|Ralph Fiennes|Naomie Harris                     908561013
# ...

# %%
#второй способ - вытаскивать актеров из предварительно созданного списка
d = data.cast.str.split('|').sum()
# и по отфильтрованному датафрейму за 2012 г искать актера с минимальной прибылью
pd.Series({x: data2012[data2012.cast.str.contains(x)].profit.sum() 
           for x in d}).idxmin()
# Out:
# 'Kirsten Dunst'

# %%
#третий способ - сразу фильтровать по году и одновременно бежать по списку актеров
pd.Series({x: data[data.release_year == 2012][data.cast.str.contains(x)].profit.sum() 
           for x in d}).idxmin()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 'Kirsten Dunst'

# %%
answer_ls.append(3)

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
#отфильтровываем датафрейм - выбираем те фильмы, где бюджет выше среднего
HPdata = data[data.budget > data.budget.mean()]

# %%
Counter(HPdata.cast.str.split('|').sum()).most_common()
# Out:
# [('Matt Damon', 18),
#  ('Adam Sandler', 17),
#  ('Angelina Jolie', 16),
#  ('Tom Cruise', 15),
#  ('Samuel L. Jackson', 15),
#  ('Eddie Murphy', 15),
#  ('Mark Wahlberg', 14),
#  ('Hugh Jackman', 14),
#  ('Ben Stiller', 14),
#  ('Jamie Foxx', 14),
#  ('Russell Crowe', 14),
#  ('Johnny Depp', 13),
#  ('Jude Law', 13),
#  ('Bruce Willis', 13),
#  ('Will Smith', 13),
#  ('Dwayne Johnson', 12),
#  ('Ian McKellen', 12),
#  ('Brad Pitt', 12),
#  ('Owen Wilson', 12),
#  ('Cameron Diaz', 12),
#  ('Nicolas Cage', 12),
#  ('Robert De Niro', 12),
#  ('Leonardo DiCaprio', 11),
#  ('Daniel Craig', 11),
#  ('Robert Downey Jr.', 11),
#  ('Steve Buscemi', 11),
#  ('Vin Diesel', 10),
#  ('Mark Ruffalo', 10),
#  ('Jack Black', 10),
#  ('Denzel Washington', 10),
#  ('Emma Watson', 10),
#  ('Gary Oldman', 10),
#  ('Tom Hanks', 10),
#  ('Orlando Bloom', 10),
#  ('Ralph Fiennes', 9),
#  ('Cate Blanchett', 9),
#  ('Michael Caine', 9),
#  ('Ewan McGregor', 9),
#  ('Paul Bettany', 9),
# ...

# %%
answer_ls.append(3)

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
NCdata = data[data.cast.str.contains("Nicolas Cage")]

# %%
Counter(NCdata.genres.str.split('|').sum()).most_common()
# Out:
# [('Action', 17),
#  ('Thriller', 15),
#  ('Drama', 12),
#  ('Crime', 10),
#  ('Fantasy', 8),
#  ('Adventure', 7),
#  ('Comedy', 6),
#  ('Science Fiction', 4),
#  ('Mystery', 3),
#  ('Animation', 3),
#  ('Family', 3),
#  ('History', 2),
#  ('War', 1),
#  ('Horror', 1),
#  ('Romance', 1)]

# %%
answer_ls.append(2)

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
Counter(data.production_companies.str.split('|').sum()).most_common()
# Out:
# [('Universal Pictures', 173),
#  ('Warner Bros.', 168),
#  ('Paramount Pictures', 122),
#  ('Columbia Pictures', 117),
#  ('Twentieth Century Fox Film Corporation', 109),
#  ('Relativity Media', 99),
#  ('New Line Cinema', 88),
#  ('Walt Disney Pictures', 82),
#  ('Village Roadshow Pictures', 63),
#  ('DreamWorks SKG', 62),
#  ('Touchstone Pictures', 58),
#  ('Regency Enterprises', 49),
#  ('Metro-Goldwyn-Mayer (MGM)', 48),
#  ('Columbia Pictures Corporation', 47),
#  ('Dune Entertainment', 44),
#  ('Summit Entertainment', 41),
#  ('Miramax Films', 39),
#  ('Dimension Films', 37),
#  ('Lionsgate', 35),
#  ('Fox 2000 Pictures', 35),
#  ('Legendary Pictures', 34),
#  ('Spyglass Entertainment', 32),
#  ('Screen Gems', 31),
#  ('Revolution Studios', 30),
#  ('Original Film', 29),
#  ('New Regency Pictures', 28),
#  ('The Weinstein Company', 28),
#  ('Working Title Films', 27),
#  ('DreamWorks Animation', 26),
#  ('Imagine Entertainment', 25),
#  ('Scott Free Productions', 24),
# ...

# %%
answer_ls.append(1)

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
#отфильтровываем датафрейм по 2015 году
data2015 = data[data.release_year == 2015]

# %%
Counter(data2015.production_companies.str.split('|').sum()).most_common()
# Out:
# [('Warner Bros.', 12),
#  ('Universal Pictures', 10),
#  ('Twentieth Century Fox Film Corporation', 8),
#  ('Paramount Pictures', 7),
#  ('Columbia Pictures', 7),
#  ('TSG Entertainment', 6),
#  ('Legendary Pictures', 5),
#  ('New Line Cinema', 5),
#  ('RatPac-Dune Entertainment', 5),
#  ('Blumhouse Productions', 5),
#  ('Village Roadshow Pictures', 4),
#  ('Regency Enterprises', 4),
#  ('Walt Disney Pictures', 4),
#  ('Studio Babelsberg', 4),
#  ('Working Title Films', 4),
#  ('Metro-Goldwyn-Mayer (MGM)', 4),
#  ('Dentsu', 3),
#  ('Summit Entertainment', 3),
#  ('Media Rights Capital', 3),
#  ('Scott Free Productions', 3),
#  ('Film4', 3),
#  ('Lionsgate', 3),
#  ('Sony Pictures Entertainment (SPE)', 3),
#  ('Fox 2000 Pictures', 3),
#  ('Cross Creek Pictures', 3),
#  ('Moving Picture Company (MPC)', 3),
#  ('LStar Capital', 3),
#  ('Amblin Entertainment', 2),
#  ('Fuji Television Network', 2),
#  ('NeoReel', 2),
#  ('Bad Robot', 2),
#  ('Original Film', 2),
# ...

# %%
answer_ls.append(4)

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
#отфильтровала датафрейм по комедиям
Cdata = data[data.genres.str.contains("Comedy")]

# %%
#делаем список из всех компаний, разделяя его по |
с = data.production_companies.str.split('|').sum()

# %%
pd.Series({x: Cdata[Cdata.production_companies.str.contains(x)].profit.sum() 
           for x in с}).idxmax()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py:1843: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# 'Universal'

# %%
pd.Series({x: data[(data.genres.str.contains('Comedy'))&(data.production_companies.str.contains(x))].profit.sum() 
           for x in с}).idxmax()
#третий способ - сразу фильтровать по жанру и одновременно бежать по списку компаний
# Out:
# 'Universal'

# %%
answer_ls.append(2)

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
#отфильтровала датафрейм по 2012
data2012 = data[data.release_year == 2012]

# %%
#делаем список из всех компаний, разделяя его по |
с = data.production_companies.str.split('|').sum()

# %%
pd.Series({x: data2012[data2012.production_companies.str.contains(x)].profit.sum() 
           for x in с}).idxmax()
# Out:
# 'Columbia Pictures'

# %%
answer_ls.append(1)

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
#находим минимальнуб прибыль для компании РР
data[data.production_companies.str.contains("Paramount Pictures")].profit.min()
# Out:
# -64831034

# %%
#фильтруем по этой минимальной прибыли
data[data.profit == -64831034]
# Out:
#        imdb_id  popularity     budget   revenue        original_title  \
# 926  tt0267626     0.72233  100000000  35168966  K-19: The Widowmaker
#
#                                                   cast         director  \
# 926  Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...  Kathryn Bigelow
#
#                       tagline  \
# 926  Fate has found its hero.
#
#                                               overview  runtime  \
# 926  When Russia's first nuclear submarine malfunct...      138
#
#                      genres  \
# 926  Thriller|Drama|History
#
#                                   production_companies release_date  \
# 926  Paramount Pictures|Intermedia Films|National G...    7/19/2002
#
#      vote_count  vote_average  release_year    profit
# 926         146           6.0          2002 -64831034

# %%
#пробуем объединить первые 2 шага
data[data.profit == data[data.production_companies.str.contains("Paramount Pictures")].profit.min()]
# Out:
#        imdb_id  popularity     budget   revenue        original_title  \
# 926  tt0267626     0.72233  100000000  35168966  K-19: The Widowmaker
#
#                                                   cast         director  \
# 926  Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...  Kathryn Bigelow
#
#                       tagline  \
# 926  Fate has found its hero.
#
#                                               overview  runtime  \
# 926  When Russia's first nuclear submarine malfunct...      138
#
#                      genres  \
# 926  Thriller|Drama|History
#
#                                   production_companies release_date  \
# 926  Paramount Pictures|Intermedia Films|National G...    7/19/2002
#
#      vote_count  vote_average  release_year    profit
# 926         146           6.0          2002 -64831034

# %%
#выбираем только название фильма
data.original_title[data.profit == data[data.production_companies.str.contains("Paramount Pictures")].profit.min()]
# Out:
# 926    K-19: The Widowmaker
# Name: original_title, dtype: object

# %%
answer_ls.append(1)

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
data4 = data.groupby(['release_year'])['profit'].sum().sort_values(ascending=False)
data4
# Out:
# release_year
# 2015    18668572378
# 2014    16397812953
# 2012    16077001687
# 2013    15243179791
# 2011    14730241341
# 2009    13423744372
# 2010    13117292530
# 2008    11663881990
# 2007    11565911801
# 2004     9634180720
# 2003     9228823312
# 2002     9002361487
# 2005     8981925558
# 2006     8691077320
# 2001     7950614865
# 2000     6101399805
# Name: profit, dtype: int64

# %%
answer_ls.append(5)

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
#фильтр только тем строкам, где есть указанная студия
WBdata = data[data.production_companies.str.contains("Warner Bros")]

# %%
#из отфильтрованного датафрейма (только 1 студия) группируем по году сумму прибыли
data5 = WBdata.groupby(['release_year'])['profit'].sum().sort_values(ascending=False)
data5
# Out:
# release_year
# 2014    2295464519
# 2007    2201675217
# 2008    2134595031
# 2010    1974712985
# 2011    1871393682
# 2003    1855493377
# 2009    1822454136
# 2013    1636453400
# 2004    1631933725
# 2005    1551980298
# 2001    1343545668
# 2012    1258020056
# 2002    1022709901
# 2015     870368348
# 2006     620170743
# 2000     452631386
# Name: profit, dtype: int64

# %%
#вот тут попробовала вытащить год не из заранее подготовленного списка, а напрямую из датафрейма
(pd.Series({x: data[(data.production_companies.str.contains('Warner Bros.')) & 
                                     (data.release_year == x)].profit.sum() for x in set(data.release_year)}))\
                 .idxmax()
# Out:
# 2014

# %%
answer_ls.append(1)

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
#обрезала месяц (первые 2 символа - 0 и 1)
data['release_date'] = data['release_date'].apply(lambda x: str(x)[:2])
data['release_date']
# Out:
# 0       6/
# 1       5/
# 2       3/
# 3       12
# 4       4/
#         ..
# 1885    7/
# 1886    10
# 1887    6/
# 1888    2/
# 1889    7/
# Name: release_date, Length: 1890, dtype: object

# %%
#убрала слеш из месяца
data['release_date'] = data['release_date'].apply(lambda x: x.replace('/', ''))
data['release_date']
# Out:
# 0        6
# 1        5
# 2        3
# 3       12
# 4        4
#         ..
# 1885     7
# 1886    10
# 1887     6
# 1888     2
# 1889     7
# Name: release_date, Length: 1890, dtype: object

# %%
Counter(data.release_date).most_common()
# Out:
# [('9', 227),
#  ('12', 191),
#  ('10', 186),
#  ('8', 161),
#  ('3', 156),
#  ('4', 149),
#  ('6', 147),
#  ('11', 146),
#  ('7', 142),
#  ('5', 140),
#  ('2', 135),
#  ('1', 110)]

# %%
answer_ls.append(4)

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
#отфильтровываем датафрейм по летним месяцам и находим длину
len(data[(data.release_date == '6')|(data.release_date == '7')|(data.release_date == '8')])
# Out:
# 450

# %%
answer_ls.append(2)

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
#отфильтровываем датафрейм по зимним месяцам
windata = data[(data.release_date == '12')|(data.release_date == '1')|(data.release_date == '2')]

# %%
Counter(windata.director.str.split('|').sum()).most_common()
# Out:
# [('Peter Jackson', 7),
#  ('Clint Eastwood', 6),
#  ('Steven Soderbergh', 6),
#  ('Shawn Levy', 4),
#  ('Nancy Meyers', 4),
#  ('Martin Scorsese', 4),
#  ('Adam Shankman', 4),
#  ('Ridley Scott', 3),
#  ('Rob Marshall', 3),
#  ('Tim Burton', 3),
#  ('Steve Carr', 3),
#  ('Patrick Lussier', 3),
#  ('Donald Petrie', 3),
#  ('Marc Lawrence', 3),
#  ('Lasse HallstrÃ¶m', 3),
#  ('Edward Zwick', 3),
#  ('Jason Friedberg', 3),
#  ('Aaron Seltzer', 3),
#  ('Peter Farrelly', 3),
#  ('Steven Spielberg', 3),
#  ('Wayne Wang', 3),
#  ('Quentin Tarantino', 2),
#  ('Adam McKay', 2),
#  ('Michael Mann', 2),
#  ('Glenn Ficarra', 2),
#  ('John Requa', 2),
#  ('Pierre Morel', 2),
#  ('Wes Anderson', 2),
#  ('Paul Thomas Anderson', 2),
#  ('Jaume Collet-Serra', 2),
#  ('George Clooney', 2),
#  ('Shana Feste', 2),
#  ('Ken Kwapis', 2),
#  ('Henry Selick', 2),
#  ('P.J. Hogan', 2),
#  ('David S. Goyer', 2),
#  ('Paul McGuigan', 2),
#  ('Marcus Nispel', 2),
#  ('Andrzej Bartkowiak', 2),
# ...

# %%
answer_ls.append(5)

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
#сделала группировку по 2м параметрам - месяц и год
dataPM = data.groupby(['release_date', 'release_year'])['profit'].sum().sort_values(ascending=False)
display(dataPM)
# Out:
# release_date  release_year
# 6             2015            3757679861
# 12            2009            3423239738
# 6             2012            2965481705
# 12            2015            2777325507
# 6             2007            2764341802
#                                  ...
# 4             2000             124362846
# 1             2007              91188025
# 9             2001              21874909
# 1             2002              13657034
#               2000             -26344591
# Name: profit, Length: 192, dtype: int64

# %%
#сделала группировку по 2м параметрам - месяц и год и добавила вывод первых 15 значений, ну чтобы точно убедиться какой месяц
dataPM = data.groupby(['release_date', 'release_year'])['profit'].sum().sort_values(ascending=False).head(15)
display(dataPM)
# Out:
# release_date  release_year
# 6             2015            3757679861
# 12            2009            3423239738
# 6             2012            2965481705
# 12            2015            2777325507
# 6             2007            2764341802
# 4             2015            2602565518
# 6             2010            2449561498
# 11            2012            2412991475
# 5             2004            2412578839
# 6             2013            2411922008
# 7             2011            2331661017
# 5             2014            2279978281
# 6             2006            2098059770
# 11            2013            2047380217
#               2014            2043956761
# Name: profit, dtype: int64

# %%
answer_ls.append(2)

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
#создаем новую колонку с длинной по кол-ву символов в названии фильмов
data['len_tile'] = data.original_title.apply(lambda x: len(x))

# %%
#делаем группировку по компаниям и считаем среднее для кол-ва символов в названии фильма
data6 = data.groupby(['production_companies'])['len_tile'].mean().sort_values(ascending=False)
data6
# Out:
# production_companies
# Twentieth Century Fox Film Corporation|Four By Two Productions                                                          83.0
# Walt Disney|Walden Media                                                                                                62.0
# Walt Disney Pictures|21 Laps Entertainment|Jim Henson Company, The                                                      59.0
# Plan B Entertainment|Virtual Studios|Scott Free Productions|Alberta Film Entertainment|Warner Bros.                     58.0
# Dune Entertainment|Fox 2000 Pictures|Walden Media                                                                       56.0
#                                                                                                                         ...
# Sunswept Entertainment|Warner Bros.|Metro-Goldwyn-Mayer (MGM)                                                            3.0
# ...

# %%
#второй вариант 
l = pd.Series({x: data[data.production_companies.str.contains(x)].len_tile.max()
           for x in с})
l
# Out:
# Universal Studios          19.0
# Amblin Entertainment       35.0
# Legendary Pictures         22.0
# Fuji Television Network    14.0
# Dentsu                     24.0
#                            ...
# JLT Productions            12.0
# Springwood Productions      5.0
# Capella International      36.0
# KC Medien AG               36.0
# Nora Ephron Productions    10.0
# Length: 1772, dtype: float64

# %%
l.sort_values(ascending=False)
# Out:
# Four By Two Productions                                 83.0
# Twentieth Century Fox Film Corporation                  83.0
# Twentieth Century Fox                                   83.0
# Walden Media                                            62.0
# Walt Disney                                             62.0
#                                                         ...
# Warner Independent Pictures (WIP)                        NaN
# The Movie Network (TMN)                                  NaN
# Munich Film Partners & Company (MFP) MI2 Productions     NaN
# Danmarks Radio (DR)                                      NaN
# Munich Film Partners & Company (MFP) ROE Production      NaN
# Length: 1772, dtype: float64

# %%
answer_ls.append(5)

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
#создаем новую колонку с длинной по кол-ву слов названии фильмов
data['sym_tile'] = data.original_title.apply(lambda x: len(x.split(' ')))

# %%
data7 = data.groupby(['production_companies'])['sym_tile'].mean().sort_values(ascending=False)
data7
# Out:
# production_companies
# Twentieth Century Fox Film Corporation|Four By Two Productions                                                       12.0
# Walt Disney|Walden Media                                                                                             11.0
# Village Roadshow Pictures                                                                                            10.0
# Walt Disney Pictures|21 Laps Entertainment|Jim Henson Company, The                                                   10.0
# Plan B Entertainment|Virtual Studios|Scott Free Productions|Alberta Film Entertainment|Warner Bros.                  10.0
#                                                                                                                      ...
# Imagine Entertainment|Malpaso Productions|Relativity Media                                                            1.0
# ...

# %%
#второй вариант 
l2 = pd.Series({x: data[data.production_companies.str.contains(x)].sym_tile.max()
           for x in с})
l2
# Out:
# Universal Studios          3.0
# Amblin Entertainment       6.0
# Legendary Pictures         5.0
# Fuji Television Network    2.0
# Dentsu                     4.0
#                           ...
# JLT Productions            3.0
# Springwood Productions     1.0
# Capella International      6.0
# KC Medien AG               6.0
# Nora Ephron Productions    2.0
# Length: 1772, dtype: float64

# %%
l2.sort_values(ascending=False)
#вот тут конечно несколько с максимальным значением, поэтому только выбирать из имеющихся ответов
# Out:
# Twentieth Century Fox Film Corporation                  12.0
# Twentieth Century Fox                                   12.0
# Four By Two Productions                                 12.0
# Disney                                                  11.0
# Walt Disney                                             11.0
#                                                         ...
# Warner Independent Pictures (WIP)                        NaN
# The Movie Network (TMN)                                  NaN
# Munich Film Partners & Company (MFP) MI2 Productions     NaN
# Danmarks Radio (DR)                                      NaN
# Munich Film Partners & Company (MFP) ROE Production      NaN
# Length: 1772, dtype: float64

# %%
answer_ls.append(5)

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
Counter(data.original_title.str.split(' ').sum()).most_common()
# Out:
# [('The', 434),
#  ('of', 185),
#  ('the', 165),
#  ('2', 48),
#  ('and', 48),
#  ('&', 38),
#  ('in', 36),
#  ('A', 31),
#  ('to', 31),
#  ('a', 28),
#  ('Man', 27),
#  ('Movie', 19),
#  ('I', 19),
#  ('3', 16),
#  ('Big', 16),
#  ('Love', 16),
#  ('Me', 16),
#  ('Night', 14),
#  ('Day', 14),
#  ('Last', 13),
#  ('Black', 13),
#  ('for', 13),
#  ('You', 13),
#  ('My', 13),
#  ('House', 13),
#  ('Part', 12),
#  ('Up', 11),
#  ('with', 11),
#  ('Life', 11),
#  ('Dark', 11),
#  ('-', 10),
#  ('Good', 10),
#  ('In', 10),
#  ('Little', 10),
#  ('Game', 10),
#  ('Men', 10),
#  ('Harry', 10),
#  ('II', 10),
#  ('War', 10),
#  ('World', 9),
#  ('Legend', 9),
#  ('We', 9),
#  ('Days', 9),
#  ('American', 9),
#  ('Mr.', 9),
#  ('Dead', 9),
#  ('Potter', 9),
#  ('Star', 8),
#  ('Out', 8),
#  ('Boy', 8),
#  ('White', 8),
#  ('How', 8),
#  ('Year', 8),
#  ('Fire', 8),
#  ('Bad', 8),
#  ('on', 8),
#  ('Never', 8),
#  ('2:', 8),
#  ('Road', 7),
#  ('Secret', 7),
#  ('Perfect', 7),
#  ('All', 7),
# ...

# %%
len(Counter(data.original_title.str.split(' ').sum()).most_common())
# Out:
# 2477

# %%
#второй вариант решения, так точнее
#заменила все буквы на маленькие
data['original_title'] = data.original_title.apply(lambda x:str(x).lower())

# %%
Counter(data.original_title.str.split(' ').sum()).most_common()
# Out:
# [('the', 599),
#  ('of', 185),
#  ('a', 59),
#  ('2', 48),
#  ('and', 48),
#  ('in', 46),
#  ('&', 38),
#  ('to', 32),
#  ('man', 27),
#  ('movie', 19),
#  ('i', 19),
#  ('3', 16),
#  ('big', 16),
#  ('love', 16),
#  ('me', 16),
#  ('for', 15),
#  ('night', 14),
#  ('day', 14),
#  ('with', 14),
#  ('last', 13),
#  ('black', 13),
#  ('you', 13),
#  ('my', 13),
#  ('house', 13),
#  ('part', 12),
#  ('on', 12),
#  ('up', 11),
#  ('life', 11),
#  ('dark', 11),
#  ('-', 10),
#  ('good', 10),
#  ('little', 10),
#  ('game', 10),
#  ('men', 10),
#  ('harry', 10),
#  ('ii', 10),
#  ('war', 10),
#  ('world', 9),
#  ('legend', 9),
#  ('we', 9),
#  ('days', 9),
#  ('american', 9),
#  ('mr.', 9),
#  ('dead', 9),
#  ('potter', 9),
#  ('star', 8),
#  ('out', 8),
#  ('boy', 8),
#  ('white', 8),
#  ('at', 8),
#  ('how', 8),
#  ('year', 8),
#  ('fire', 8),
#  ('bad', 8),
#  ('never', 8),
#  ('2:', 8),
#  ('road', 7),
#  ('secret', 7),
#  ('perfect', 7),
#  ('all', 7),
#  ('from', 7),
#  ('home', 7),
# ...

# %%
len(Counter(data.original_title.str.split(' ').sum()).most_common())
# Out:
# 2462

# %%
answer_ls.append(3)

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
data100 = np.percentile(data.vote_average, 99)
data100
# Out:
# 7.8

# %%
#получаем значение 7.8 - то есть 99% меньше чем 7.8, но подставляем в фильтр 7.9, так меньше список
bestdata = data[data.vote_average >= 7.9]

# %%
bestdata.original_title
# Out:
# 9                                          inside out
# 34                                               room
# 118                                      interstellar
# 119                           guardians of the galaxy
# 125                                the imitation game
# 128                                         gone girl
# 138                          the grand budapest hotel
# 370                                         inception
# 600                                   the dark knight
# 873                                       the pianist
# 1082    the lord of the rings: the return of the king
# 1184                          the wolf of wall street
# 1192                                 12 years a slave
# 1801                                          memento
# Name: original_title, dtype: object

# %%
# 2й способ
data123 = data.groupby(['original_title'])['vote_average'].sum().sort_values(ascending=False)
print(data123.head(19))
#1890|100 ~ 19
# Out:
# original_title
# the gift                                             12.8
# fantastic four                                       10.0
# the dark knight                                       8.1
# inside out                                            8.0
# interstellar                                          8.0
# room                                                  8.0
# the imitation game                                    8.0
# guardians of the galaxy                               7.9
# the pianist                                           7.9
# memento                                               7.9
# the lord of the rings: the return of the king         7.9
# gone girl                                             7.9
# the wolf of wall street                               7.9
# inception                                             7.9
# 12 years a slave                                      7.9
# the grand budapest hotel                              7.9
# ...

# %%
answer_ls.append(1)

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
import re
#ищем 2х актеров сразу
s1 = data.cast.str.contains(r'(?=.*Johnny Depp)(?=.*Helena Bonham Carter)',regex=True)
s1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1885    False
# 1886    False
# 1887    False
# 1888    False
# 1889    False
# Name: cast, Length: 1890, dtype: bool

# %%
#делаем из сериз датафрейм, чтобы потом фильтровать удобнее
s_df1 = s1.reset_index()
s_df1
# Out:
#       index   cast
# 0         0  False
# 1         1  False
# 2         2  False
# 3         3  False
# 4         4  False
# ...     ...    ...
# 1885   1885  False
# 1886   1886  False
# 1887   1887  False
# 1888   1888  False
# 1889   1889  False
#
# [1890 rows x 2 columns]

# %%
#отфильтровываем только те, где true и считаем кол-во
len(s_df1[s_df1.cast == True])
# Out:
# 6

# %%
s2 =data.cast.str.contains(r'(?=.*Hugh Jackman)(?=.*Ian McKellen)',regex=True)
s2
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1885     True
# 1886    False
# 1887    False
# 1888    False
# 1889    False
# Name: cast, Length: 1890, dtype: bool

# %%
#делаем из сериз датафрейм, чтобы потом фильтровать удобнее
s_df2 = s2.reset_index()
s_df2
# Out:
#       index   cast
# 0         0  False
# 1         1  False
# 2         2  False
# 3         3  False
# 4         4  False
# ...     ...    ...
# 1885   1885   True
# 1886   1886  False
# 1887   1887  False
# 1888   1888  False
# 1889   1889  False
#
# [1890 rows x 2 columns]

# %%
#отфильтровываем только те, где true и считаем кол-во
len(s_df2[s_df2.cast == True])
# Out:
# 5

# %%
s3 =data.cast.str.contains(r'(?=.*Vin Diesel)(?=.*Paul Walker)',regex=True)
s3
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1885    False
# 1886    False
# 1887    False
# 1888    False
# 1889    False
# Name: cast, Length: 1890, dtype: bool

# %%
s_df3 = s3.reset_index()
s_df3
# Out:
#       index   cast
# 0         0  False
# 1         1  False
# 2         2  False
# 3         3  False
# 4         4   True
# ...     ...    ...
# 1885   1885  False
# 1886   1886  False
# 1887   1887  False
# 1888   1888  False
# 1889   1889  False
#
# [1890 rows x 2 columns]

# %%
#отфильтровываем только те, где true и считаем кол-во
len(s_df3[s_df3.cast == True])
# Out:
# 5

# %%
s4 =data.cast.str.contains(r'(?=.*Adam Sandler)(?=.*Kevin James)',regex=True)
s4
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1885    False
# 1886    False
# 1887    False
# 1888    False
# 1889    False
# Name: cast, Length: 1890, dtype: bool

# %%
s_df4 = s4.reset_index()
s_df4
# Out:
#       index   cast
# 0         0  False
# 1         1  False
# 2         2  False
# 3         3  False
# 4         4  False
# ...     ...    ...
# 1885   1885  False
# 1886   1886  False
# 1887   1887  False
# 1888   1888  False
# 1889   1889  False
#
# [1890 rows x 2 columns]

# %%
len(s_df4[s_df4.cast == True])
# Out:
# 5

# %%
s5 =data.cast.str.contains(r'(?=.*Daniel Radcliffe)(?=.*Rupert Grint)',regex=True)
s5
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1885    False
# 1886    False
# 1887    False
# 1888    False
# 1889    False
# Name: cast, Length: 1890, dtype: bool

# %%
s_df5 = s5.reset_index()
s_df5
# Out:
#       index   cast
# 0         0  False
# 1         1  False
# 2         2  False
# 3         3  False
# 4         4  False
# ...     ...    ...
# 1885   1885  False
# 1886   1886  False
# 1887   1887  False
# 1888   1888  False
# 1889   1889  False
#
# [1890 rows x 2 columns]

# %%
len(s_df5[s_df5.cast == True])
# Out:
# 8

# %%
answer_ls.append(5)

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
#считаем сколько всего каждый режисер снял фильмов
totaldir = data.groupby(['director'])['original_title'].count()
totaldir
# Out:
# director
# Aaron Seltzer|Jason Friedberg    1
# Adam McKay                       6
# Adam Shankman                    8
# Adam Wingard                     1
# Adrian Lyne                      1
#                                 ..
# Wong Kar-wai                     1
# Woody Allen                      3
# Xavier Gens                      1
# Zack Snyder                      6
# Zal Batmanglij                   1
# Name: original_title, Length: 958, dtype: int64

# %%
td = totaldir.reset_index()
td
# Out:
#                           director  original_title
# 0    Aaron Seltzer|Jason Friedberg               1
# 1                       Adam McKay               6
# 2                    Adam Shankman               8
# 3                     Adam Wingard               1
# 4                      Adrian Lyne               1
# ..                             ...             ...
# 953                   Wong Kar-wai               1
# 954                    Woody Allen               3
# 955                    Xavier Gens               1
# 956                    Zack Snyder               6
# 957                 Zal Batmanglij               1
#
# [958 rows x 2 columns]

# %%
#отфильтровываем датафрейм только для тех фильмов, у ктр сборы выше бюджета, то есть с прибылью
profitfilms = data[data.profit > 0]

# %%
#считаем сколько всего каждый режисер снял прибыльных фильмов
profitdir = profitfilms.groupby(['director'])['original_title'].count()
profitdir
# Out:
# director
# Aaron Seltzer|Jason Friedberg    1
# Adam McKay                       6
# Adam Shankman                    7
# Adrian Lyne                      1
# Alan Poul                        1
#                                 ..
# Wolfgang Petersen                3
# Wong Kar-wai                     1
# Woody Allen                      3
# Xavier Gens                      1
# Zack Snyder                      6
# Name: original_title, Length: 774, dtype: int64

# %%
pd = profitdir.reset_index()
pd
# Out:
#                           director  original_title
# 0    Aaron Seltzer|Jason Friedberg               1
# 1                       Adam McKay               6
# 2                    Adam Shankman               7
# 3                      Adrian Lyne               1
# 4                        Alan Poul               1
# ..                             ...             ...
# 769              Wolfgang Petersen               3
# 770                   Wong Kar-wai               1
# 771                    Woody Allen               3
# 772                    Xavier Gens               1
# 773                    Zack Snyder               6
#
# [774 rows x 2 columns]

# %%
#объединяем датафреймы
joined = td.merge(pd, on='director', how='left')
joined.head()
# Out:
#                         director  original_title_x  original_title_y
# 0  Aaron Seltzer|Jason Friedberg                 1               1.0
# 1                     Adam McKay                 6               6.0
# 2                  Adam Shankman                 8               7.0
# 3                   Adam Wingard                 1               NaN
# 4                    Adrian Lyne                 1               1.0

# %%
#меняем названия колонок
joined.columns = ['director','totalfilms','profitfilms']

# %%
joined.head()
# Out:
#                         director  totalfilms  profitfilms
# 0  Aaron Seltzer|Jason Friedberg           1          1.0
# 1                     Adam McKay           6          6.0
# 2                  Adam Shankman           8          7.0
# 3                   Adam Wingard           1          NaN
# 4                    Adrian Lyne           1          1.0

# %%
#создаем новую колонку
joined['percentage'] = joined['profitfilms']/joined['totalfilms']

# %%
joined.head()
# Out:
#                         director  totalfilms  profitfilms  percentage
# 0  Aaron Seltzer|Jason Friedberg           1          1.0       1.000
# 1                     Adam McKay           6          6.0       1.000
# 2                  Adam Shankman           8          7.0       0.875
# 3                   Adam Wingard           1          NaN         NaN
# 4                    Adrian Lyne           1          1.0       1.000

# %%
joined[joined.percentage == joined.percentage.max()]
# Out:
#                           director  totalfilms  profitfilms  percentage
# 0    Aaron Seltzer|Jason Friedberg           1          1.0         1.0
# 1                       Adam McKay           6          6.0         1.0
# 4                      Adrian Lyne           1          1.0         1.0
# 7                        Alan Poul           1          1.0         1.0
# 8                      Alan Taylor           2          2.0         1.0
# ..                             ...         ...          ...         ...
# 952              Wolfgang Petersen           3          3.0         1.0
# 953                   Wong Kar-wai           1          1.0         1.0
# 954                    Woody Allen           3          3.0         1.0
# 955                    Xavier Gens           1          1.0         1.0
# 956                    Zack Snyder           6          6.0         1.0
#
# [604 rows x 4 columns]

# %%
joined[joined.director.str.contains("Quentin Tarantino")]
# Out:
#                                               director  totalfilms  \
# 710                                  Quentin Tarantino           5
# 753  Robert Rodriguez|Eli Roth|Quentin Tarantino|Ed...           1
# 755    Robert Rodriguez|Frank Miller|Quentin Tarantino           1
#
#      profitfilms  percentage
# 710          5.0         1.0
# 753          NaN         NaN
# 755          1.0         1.0

# %%
(5+1)/(5+1+1)
# Out:
# 0.8571428571428571

# %%
joined[joined.director.str.contains("Steven Soderbergh")]
# Out:
#               director  totalfilms  profitfilms  percentage
# 866  Steven Soderbergh          13         10.0    0.769231

# %%
joined[joined.director.str.contains("Robert Rodriguez")]
# Out:
#                                               director  totalfilms  \
# 279                      Frank Miller|Robert Rodriguez           1
# 752                                   Robert Rodriguez           7
# 753  Robert Rodriguez|Eli Roth|Quentin Tarantino|Ed...           1
# 754                    Robert Rodriguez|Ethan Maniquis           1
# 755    Robert Rodriguez|Frank Miller|Quentin Tarantino           1
#
#      profitfilms  percentage
# 279          NaN         NaN
# 752          6.0    0.857143
# 753          NaN         NaN
# 754          1.0    1.000000
# 755          1.0    1.000000

# %%
(6+1+1)/(1+7+1+1+1)
# Out:
# 0.7272727272727273

# %%
joined[joined.director.str.contains("Christopher Nolan")]
# Out:
#               director  totalfilms  profitfilms  percentage
# 147  Christopher Nolan           8          8.0         1.0

# %%
joined[joined.director.str.contains("Clint Eastwood")]
# Out:
#            director  totalfilms  profitfilms  percentage
# 153  Clint Eastwood          12         10.0    0.833333

# %%
answer_ls.append(4)

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 36

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
#     Id  Answer
# 0    1       4
# 1    2       2
# 2    3       3
# 3    4       2
# 4    5       1
# 5    6       5
# 6    7       2
# 7    8       1
# 8    9       4
# 9   10       5
# 10  11       3
# 11  12       1
# 12  13       1
# 13  14       4
# 14  15       5
# 15  16       1
# 16  17       3
# 17  18       3
# 18  19       2
# 19  20       1
# 20  21       4
# 21  22       2
# 22  23       1
# 23  24       1
# 24  25       5
# 25  26       1
# 26  27       4
# 27  28       2
# 28  29       5
# 29  30       2
# 30  31       5
# 31  32       5
# 32  33       3
# 33  34       1
# 34  35       5
# 35  36       4
